# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

df1 = pd.read_csv('log/20201010-003503/log.csv')
df2 = pd.read_csv('log/20201007-123703/log.csv')
df3 = pd.read_csv('log/20201008-221917/log.csv')

plt.style.use('ggplot')

dfs = [df1, df2, df3]

# %%
f = plt.figure()
for df in dfs:
    plt.plot(df[df['total_steps']>df['pretraining_steps']].reset_index()['epoch_avg_q'])

plt.legend(['tau=0.05', 'tau=0.005', 'tau=0.01'])
plt.title('Average Epoch Q Values')
plt.xlabel('epoch')
plt.ylabel('avg. q')
# Out:
# Text(0, 0.5, 'avg. q')

# %%
for df in dfs:
    df['epoch_m'] = pd.to_timedelta(df['epoch_time']).dt.total_seconds()/60

# %%
def plot_epoch_time(df, line_kws=None, scatter_kws=None, groupby=None):
    
    if not line_kws:
        line_kws= {'alpha': .7, 'linewidth': 1}
        
    if not scatter_kws:
        scatter_kws = {"s": 15}
    
    if not groupby:
        sns.regplot(x=df[df['total_steps']>df['pretraining_steps']]['total_steps'], 
                    y=df[df['total_steps']>df['pretraining_steps']]['epoch_m'],
                    marker='.', 
                    line_kws=line_kws,
                    scatter_kws=scatter_kws,
                    ci=0,
                    ax=ax, x_ci='sd')
        
    if groupby:
        sns.lineplot(x=pd.cut(df[df['total_steps']>df['pretraining_steps']]['total_steps'], bins=groupby, retbins=True)[1][:-1], 
                     y=df[df['total_steps']>df['pretraining_steps']].groupby(pd.cut(df[df['total_steps']>df['pretraining_steps']]['total_steps'], bins=groupby))['epoch_m'].mean(),
                     ax=ax)

# %%
fig, ax = plt.subplots(figsize=(8,6))

plot_epoch_time(df1, groupby=15)
# plot_epoch_time(df2, )
plot_epoch_time(df3, groupby=15)

# %%
import environment
import matplotlib.pyplot as plt
import numpy as np

# %%
env = environment.Environment()

# %%
np.save('game_won', env._grab_sct())

# %%
game_wonarray = np.load('game_won.npy')

# %%
(env._grab_sct() == game_wonarray).all()
# Out:
# True

# %%
env._is_game_won()
# Out:
# True

# %%
from selenium.webdriver.common.keys import Keys
import selenium
from selenium import webdriver

# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-25-bf7206a0847a> in <module>
# ----> 1 driver.find_element_by_xpath('/html/body/div[6]/div/div[1]/div/form/input[5]')
#
# ~\anaconda3\envs\tf_gpu\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\envs\tf_gpu\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ...
